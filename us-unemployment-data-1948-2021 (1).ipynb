# %% [markdown]
# # Introduction 😃😃¶¶
#
#
# ## US Unemployment Data (1948-2021)🙄🙄
# #### US unemployment rate based on age ranges and gender
#
# ##### Contains the monthly unemployment rate from 1948-2021.
# - Unemployment rates for men and women.
# -Unemployment category
# - [ unrate_16_to_17
# - unrate_18_to_19
# - unrate_20_to_24
# - unrate_25_to_34
# - unrate_35_to_44
# - unrate_45_to_54
# - unrate_55_over
#
#
#  #### This data is collected by the US Bureau of Labor Statistics.
#
#
# ## Mission 🙄🙄
#
# - Analyze and explore data 🤝
#
#
# # * Analyze and Explore DataSet 😃❤️🤝

# %%
#Importing the basic librarires fot analysis

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")  #using style ggplot

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import datetime as dt
import plotly.graph_objects as go
import plotly.express as px

# %%
#Importing the dataset
df =pd.read_csv("../input/unemployment-data-19482021/unemployment_rate_data.csv")


# look the data set
df.head()
# Out:
#        date  unrate  unrate_men  unrate_women  unrate_16_to_17  \
# 0  1/1/1948     4.0         4.2           3.5             10.8
# 1  2/1/1948     4.7         4.7           4.8             15.0
# 2  3/1/1948     4.5         4.5           4.4             13.2
# 3  4/1/1948     4.0         4.0           4.1              9.9
# 4  5/1/1948     3.4         3.3           3.4              6.4
#
#    unrate_18_to_19  unrate_20_to_24  unrate_25_to_34  unrate_35_to_44  \
# 0              9.6              6.6              3.6              2.6
# 1              9.5              8.0              4.0              3.2
# 2              9.3              8.6              3.5              3.2
# 3              8.1              6.8              3.5              3.1
# 4              7.2              6.3              2.8              2.5
#
#    unrate_45_to_54  unrate_55_over
# 0              2.7             3.6
# 1              3.4             4.0
# 2              2.9             3.5
# ...

# %%
# looking the shape DataSet
df.shape
# Out:
# (887, 11)

# %%
#Checking the dtypes of all the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             887 non-null    object
#  1   unrate           887 non-null    float64
#  2   unrate_men       887 non-null    float64
#  3   unrate_women     887 non-null    float64
#  4   unrate_16_to_17  887 non-null    float64
#  5   unrate_18_to_19  887 non-null    float64
#  6   unrate_20_to_24  887 non-null    float64
#  7   unrate_25_to_34  887 non-null    float64
#  8   unrate_35_to_44  887 non-null    float64
#  9   unrate_45_to_54  887 non-null    float64
#  10  unrate_55_over   887 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 76.4+ KB

# %%
#Conversion data type column - Date from object to Datetime

df["date"]=pd.to_datetime(df["date"])

# %%
#checking null value 
df.isna().sum()
# Out:
# date               0
# unrate             0
# unrate_men         0
# unrate_women       0
# unrate_16_to_17    0
# unrate_18_to_19    0
# unrate_20_to_24    0
# unrate_25_to_34    0
# unrate_35_to_44    0
# unrate_45_to_54    0
# unrate_55_over     0
# dtype: int64

# %% [markdown]
# - No missing value

# %%
# look  describe data set
df.describe().round(2)
# Out:
#        unrate  unrate_men  unrate_women  unrate_16_to_17  unrate_18_to_19  \
# count  887.00      887.00        887.00           887.00           887.00
# mean     5.76        5.63          6.03            17.94            14.82
# std      1.74        1.95          1.61             5.02             4.05
# min      2.40        1.90          2.60             5.70             5.20
# 25%      4.50        4.30          4.90            14.70            12.30
# 50%      5.50        5.30          5.80            17.80            14.60
# 75%      6.80        6.70          7.00            20.90            17.00
# max     14.40       13.30         15.70            35.80            33.30
#
#        unrate_20_to_24  unrate_25_to_34  unrate_35_to_44  unrate_45_to_54  \
# count           887.00           887.00           887.00           887.00
# mean              9.35             5.53             4.24             3.87
# std               2.80             1.92             1.44             1.35
# ...

# %% [markdown]
# # Some Visualizations 😃❤️🤝

# %%
# show the relation years to general Unrated
plt.figure(figsize=(15,7))
sns.lineplot(data=df , x="date",y="unrate")
# Out:
# <AxesSubplot:xlabel='date', ylabel='unrate'>

# %% [markdown]
# - In general, the unemployment rate is between 3-8 - during these years, but a high rise in 2020 is due to Corona

# %%
# show the relation years to Unrated men and women - interactive graph

px.scatter_3d(df,x='date',y="unrate_men",z="unrate_women",color="unrate_women")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
#  show the relation years to Unrated men and women also general Unrated
 
plt.figure(figsize=(30,10))
sns.lineplot(data=df,x="date",y="unrate",label="un rate")
sns.lineplot(data=df,x="date",y="unrate_men",label="Men")
sns.lineplot(data=df,x="date",y="unrate_women",label="Women")


plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# - The unemployment rate is about the same for men and women

# %%
# show the Unemployment category

plt.figure(figsize=(30,10))
sns.lineplot(data=df,x="date",y="unrate_16_to_17",label="unrate_16_to_17")
sns.lineplot(data=df,x="date",y="unrate_18_to_19",label="unrate_18_to_19")
sns.lineplot(data=df,x="date",y="unrate_20_to_24",label="unrate_20_to_24")
sns.lineplot(data=df,x="date",y="unrate_25_to_34",label="unrate_25_to_34")
sns.lineplot(data=df,x="date",y="unrate_35_to_44",label="unrate_35_to_44")
sns.lineplot(data=df,x="date",y="unrate_45_to_54",label="unrate_45_to_54")
sns.lineplot(data=df,x="date",y="unrate_55_over",label="unrate_55_over")

plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# - As the age increases, unemployment decreases, and this is due to experience

# %%
sns.pairplot(df)

# %%
#add new column Year for makeing group by 
df['Year']= df['date'].dt.year
avg_year=df.groupby("Year")["unrate","unrate_men","unrate_women"].mean().round(2)
avg_year
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#       unrate  unrate_men  unrate_women
# Year
# 1948    3.77        3.61          4.12
# 1949    5.91        5.91          5.96
# 1950    5.32        5.12          5.73
# 1951    3.33        2.83          4.39
# 1952    3.03        2.77          3.64
# ...      ...         ...           ...
# 2017    4.35        4.40          4.32
# 2018    3.90        3.95          3.83
# 2019    3.67        3.72          3.62
# 2020    8.09        7.81          8.38
# 2021    5.52        5.61          5.38
#
# [74 rows x 3 columns]

# %%
# Visualizations group by
avg_year.plot(figsize=(20,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
avg_cat=df.groupby("Year")["unrate_16_to_17","unrate_18_to_19","unrate_20_to_24","unrate_25_to_34","unrate_35_to_44","unrate_45_to_54","unrate_55_over"].mean().round(2)
avg_cat
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#       unrate_16_to_17  unrate_18_to_19  unrate_20_to_24  unrate_25_to_34  \
# Year
# 1948             9.90             8.57             6.16             3.21
# 1949            13.71            12.98             9.25             5.40
# 1950            13.74            11.28             7.66             4.84
# 1951             9.49             7.12             4.12             2.96
# 1952             9.93             7.22             4.59             2.62
# ...               ...              ...              ...              ...
# 2017            15.47            13.12             7.38             4.57
# 2018            13.75            12.34             6.93             3.95
# 2019            13.92            11.92             6.73             3.72
# ...

# %%
# Visualizations group by
avg_cat.plot(figsize=(20,7))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Analysis Results😃😃😃
#
# ### US unemployment rate based on age ranges and gender
# ### Contains the monthly unemployment rate from 1948-2021.
# - Unemployment rates for men and women.
# - Unemployment category
# - [ unrate_16_to_17
# - unrate_18_to_19
# - unrate_20_to_24
# - unrate_25_to_34
# - unrate_35_to_44
# - unrate_45_to_54
# - unrate_55_over
#
#
#
# - In general, the unemployment rate is between 3-8 - during these years, but a high rise in 2020 is due to Corona
#
# - The unemployment rate is about the same for men and women
#
# - As the age increases, unemployment decreases, and this is due to experience
#
#
# # Notes 😃😃😃😃
#
# - Thank for reading my analysis and my regression. 😃😃😃😃
#
# - If you any questions or advice me please write in the comment . ❤️❤️❤️❤️
#
# - If anyone has a model with a higher percentage, please tell me 🤝🤝🤝
#
#
# # Vote ❤️😃
#
# - If you liked my work vote me ,
#
#
# # The End 🤝🎉🤝🎉¶
